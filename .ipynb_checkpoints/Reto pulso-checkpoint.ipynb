# %%
import numpy as np
from matplotlib import pyplot as plt
from matplotlib import cm

# %%
dt = 0.01
dx=(dt**2)/4
ts=np.arange(-2,2,dt)
xs=np.arange(0,10,dx)

Nx=len(xs)
N=len(ts)

T,X=np.meshgrid(ts,xs)
#u0=np.sin(ts)
u0=np.exp(-ts**2)
#u0=1/np.cosh(ts)


#us=u0
us=np.ones((Nx,N))*0j
us[0]=u0
#us=np.vstack((us,u0+dt*f(u0)))
us[1]=u0+dt*f(u0)
###us[1]=us[0]+(dt/6)*()
for i in range(1,Nx-1):
    #us=np.vstack((us,2*dt*f(us[i])+us[i-1]))
    us[i+1]=(2*dt*f(us[i])+us[i-1])

fig, ax = plt.subplots(subplot_kw={"projection": "3d"})
#ax.scatter(T,X,us)
surf=ax.plot_surface(T, X, np.real(us),cmap=cm.coolwarm,
                       linewidth=0, antialiased=False)

fig.colorbar(surf, shrink=0.5, aspect=5)
plt.xlabel("tiempo")
plt.ylabel("espacio x")
plt.show()
# Out:
# C:\Users\Arif\AppData\Local\Temp\ipykernel_3924\2749012334.py:2: RuntimeWarning: overflow encountered in multiply
#   return (1j*((u)*np.conj(u)*u+(1/2)*df(df(u,dt),dt))) ###derivada de tiempo 2
# C:\Users\Arif\AppData\Local\Temp\ipykernel_3924\2749012334.py:2: RuntimeWarning: invalid value encountered in multiply
#   return (1j*((u)*np.conj(u)*u+(1/2)*df(df(u,dt),dt))) ###derivada de tiempo 2
# C:\Users\Arif\AppData\Local\Temp\ipykernel_3924\3893179341.py:23: RuntimeWarning: invalid value encountered in multiply
#   us[i+1]=(2*dt*f(us[i])+us[i-1])
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [113], line 27
#      25 fig, ax = plt.subplots(subplot_kw={"projection": "3d"})
#      26 #ax.scatter(T,X,us)
# ---> 27 surf=ax.plot_surface(T, X, np.real(us),cmap=cm.coolwarm,
#      28                        linewidth=0, antialiased=False)
#      30 fig.colorbar(surf, shrink=0.5, aspect=5)
#      31 plt.xlabel("tiempo")
#
# File c:\users\arif\appdata\local\programs\python\python39\lib\site-packages\mpl_toolkits\mplot3d\axes3d.py:1505, in Axes3D.plot_surface(self, X, Y, Z, norm, vmin, vmax, lightsource, **kwargs)
#    1502     polyc.set_facecolors(colset)
#    1504 self.add_collection(polyc)
# -> 1505 self.auto_scale_xyz(X, Y, Z, had_data)
#    1507 return polyc
#
# File c:\users\arif\appdata\local\programs\python\python39\lib\site-packages\mpl_toolkits\mplot3d\axes3d.py:581, in Axes3D.auto_scale_xyz(self, X, Y, Z, had_data)
#     579     self.xy_dataLim.update_from_data_y(Y, not had_data)
#     580 if Z is not None:
# --> 581     self.zz_dataLim.update_from_data_x(Z, not had_data)
#     582 # Let autoscale_view figure out how to use this data.
#     583 self.autoscale_view()
#
# KeyboardInterrupt:

# %%
def f(u):
    return (1j*((u)*np.conj(u)*u+(1/2)*df(df(u,dt),dt))) ###derivada de tiempo 2

# %%
#def df(y,dt):
    #t=np.arange(ti,tf,dt)
    n=len(y)
    v1=np.ones(n-1)*(1/2)
    v2=np.ones(n-1)*(-1/2)
    D=(np.diag(v1,k=1)+np.diag(v2,k=-1))/dt
    yp=np.matmul(D, y)
    yp[-1]=yp[-2]
    yp[0]=yp[1]
    ##Plot##############################################################
    #plt.plot(t,y,color='black',label='funcion')
    #plt.plot(t,yp,color='red',label='Derivada numerica')
    #plt.axis('equal')
    #plt.grid('on')
    #plt.legend()
    #plt.close()
    return yp

# %%
def df(y,dt):
    dy=np.gradient(y)
    dt=np.ones(len(y))*dt
    return dy/dt
    plt.plot(ts,dy/dt)

# %%
plt.plot(ts,df(df(us[0],dt),dt))

# %%
uu=np.ones((5,4))*0j
uu
# Out:
# array([[0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j],
#        [0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j],
#        [0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j],
#        [0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j],
#        [0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j]])

# %%
f(us[0])*dt+u0
# Out:
# array([0.01831564+6.59627224e-04j, 0.01906121+9.98836144e-04j,
#        0.01983316+1.35705529e-03j, 0.02063225+1.39542848e-03j,
#        0.02145924+1.43449058e-03j, 0.02231491+1.47423741e-03j,
#        0.02320007+1.51466397e-03j, 0.02411551+1.55576436e-03j,
#        0.02506206+1.59753177e-03j, 0.02604056+1.63995847e-03j,
#        0.02705185+1.68303575e-03j, 0.02809679+1.72675394e-03j,
#        0.02917626+1.77110234e-03j, 0.03029114+1.81606921e-03j,
#        0.03144234+1.86164178e-03j, 0.03263076+1.90780616e-03j,
#        0.03385732+1.95454740e-03j, 0.03512297+2.00184939e-03j,
#        0.03642864+2.04969489e-03j, 0.03777529+2.09806550e-03j,
#        0.0391639 +2.14694163e-03j, 0.04059542+2.19630250e-03j,
#        0.04207086+2.24612610e-03j, 0.0435912 +2.29638921e-03j,
#        0.04515745+2.34706737e-03j, 0.04677062+2.39813485e-03j,
#        0.04843173+2.44956469e-03j, 0.05014181+2.50132863e-03j,
#        0.05190189+2.55339716e-03j, 0.05371301+2.60573948e-03j,
#        0.05557621+2.65832353e-03j, 0.05749254+2.71111595e-03j,
#        0.05946306+2.76408212e-03j, 0.06148881+2.81718614e-03j,
#        0.06357087+2.87039087e-03j, 0.06571027+2.92365788e-03j,
#        0.0679081 +2.97694755e-03j, 0.0701654 +3.03021900e-03j,
#        0.07248323+3.08343016e-03j, 0.07486266+3.13653776e-03j,
#        0.07730474+3.18949740e-03j, 0.07981052+3.24226352e-03j,
#        0.08238104+3.29478947e-03j, 0.08501734+3.34702753e-03j,
#        0.08772047+3.39892894e-03j, 0.09049144+3.45044396e-03j,
#        0.09333128+3.50152188e-03j, 0.09624098+3.55211110e-03j,
#        0.09922155+3.60215918e-03j, 0.10227398+3.65161284e-03j,
#        0.10539922+3.70041811e-03j, 0.10859825+3.74852029e-03j,
#        0.11187199+3.79586410e-03j, 0.11522138+3.84239367e-03j,
#        0.11864731+3.88805268e-03j, 0.12215067+3.93278440e-03j,
#        0.12573233+3.97653177e-03j, 0.12939313+4.01923749e-03j,
#        0.13313389+4.06084408e-03j, 0.13695539+4.10129401e-03j,
#        0.14085842+4.14052977e-03j, 0.14484371+4.17849396e-03j,
#        0.14891196+4.21512938e-03j, 0.15306387+4.25037918e-03j,
